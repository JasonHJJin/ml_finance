# %%
import pandas as pd

# %%
df = pd.read_csv("./bank-additional-full.csv", sep=';')
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
print(df.dtypes)
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
print(df["y"].value_counts())
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# yes's have to increase to even out the ratio

# %%
strings_of_unknown = ["unknown", "na", "N/A", "n/a"]
df[~df.job.str.contains("|".join(strings_of_unknown))]
df[~df.marital.str.contains("|".join(strings_of_unknown))]
df[~df.education.str.contains("|".join(strings_of_unknown))]
df[~df.default.str.contains("|".join(strings_of_unknown))]
df[~df.housing.str.contains("|".join(strings_of_unknown))]
df[~df.loan.str.contains("|".join(strings_of_unknown))]
df[~df.contact.str.contains("|".join(strings_of_unknown))]
df[~df.month.str.contains("|".join(strings_of_unknown))]
df[~df.day_of_week.str.contains("|".join(strings_of_unknown))]

# %%
df
# Out:
#        age         job  marital          education default housing loan  \
# 0       56   housemaid  married           basic.4y      no      no   no
# 2       37    services  married        high.school      no     yes   no
# 3       40      admin.  married           basic.6y      no      no   no
# 4       56    services  married        high.school      no      no  yes
# 9       25    services   single        high.school      no     yes   no
# ...    ...         ...      ...                ...     ...     ...  ...
# 41178   62     retired  married  university.degree      no      no   no
# 41180   36      admin.  married  university.degree      no      no   no
# 41181   37      admin.  married  university.degree      no     yes   no
# 41182   29  unemployed   single           basic.4y      no     yes   no
# 41185   56     retired  married  university.degree      no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
df['age'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['cons.price.idx'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df["nr.employed"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The number of employees have significantly increased over the past few quarters.

# %%
import seaborn as sns
# import matplotlib.pyplot as plt
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', annot_kws={'size':6})
# plt.title('Correlation matrix of numeric features')
# plt.show()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import 
from sklearn.metrics import accuracy_score

categorical_features=[
    "job",
    "marital",
    "education",
    "default",
    "housing",
    "loan",
    "contact",
    "month",
    "day_of_week",
    "poutcome"
]
numerical_features = [
    "age",
    "duration",
    "campaign",
    "pdays",
    "previous"
#     "emp.var.rate",
#     "cons.price.idx",
#     "cons.conf.idx",
#     "euribor3m",
#     "nr.employed"
]

encoder = OneHotEncoder()
encoder.fit(df)
one_hot_encoded_data = encoder.transform(df).toarray()

target = df["y"]
one_hot_df = pd.get_dummies(df, columns = categorical_features)
cat_df = df[categorical_features]
num_df = df[numerical_features]
X_dev, X_test, y_dev, y_test = train_test_split(one_hot_encoded_data,target,test_size=0.2,random_state=42)

# %%
model = LogisticRegression()
model.fit(X_dev, y_dev)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  1.0
